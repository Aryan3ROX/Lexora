# %%
import torch
from sentence_transformers import SentenceTransformer
from sentence_transformers.util import cos_sim

# %%
# Load book embedder
data = torch.load("artifacts/embedder/book_embeddings.pt", map_location="cpu")
emb = data["embeddings"]
meta = data["meta"]
titles = meta["titles"]

fine_tuned_model = SentenceTransformer('./artifacts/fine_tuned_book_embedder')

# %%
user_query = "fantasy, magical school, wizards, students"
query_embedding = fine_tuned_model.encode(user_query, convert_to_tensor=True).cpu()

# Find the 20 most similar books using cosine similarity
cosine_scores = cos_sim(query_embedding, emb)
top_results = torch.topk(cosine_scores[0], k=20)

print(f"\nTop 20 results for the query: '{user_query}'")
indices = top_results.indices.cpu().tolist()
scores = top_results.values.cpu().tolist()
for score, idx in zip(scores, indices):
    print(f"- {titles[idx]} (Score: {score:.4f})")
# Out:
# Top 20 results for the query: 'fantasy, magical school, wizards, students'
# - The Last Wizard (Score: 0.5805)
# - So You Want to Be a Wizard (Score: 0.5769)
# - The Magicians (Score: 0.5752)
# - The Wizard in the Woods (Score: 0.5679)
# - Kaytek the Wizard (Score: 0.5470)
# - The Magician King (Score: 0.5382)
# - The Novice (Score: 0.5322)
# - The Wizard and the Witch (Score: 0.5210)
# - A Bad Spell in Yurt (Score: 0.5209)
# - The Other Ones (Score: 0.5153)
# - Od Magic (Score: 0.5140)
# - The Wizard Test (Score: 0.5075)
# - Septimus Heap: The Magykal Papers (Score: 0.5074)
# - Igraine The Brave (Score: 0.5036)
# - The Lives of Christopher Chant (Score: 0.5033)
# - Witch Week (Score: 0.4969)
# - Enchanted, Inc. (Score: 0.4947)
# - The Wise Man's Fear (Score: 0.4937)
# - Archer's Goon (Score: 0.4912)
# - The Outstretched Shadow (Score: 0.4863)
